# %%
import pandas as pd
import os as os 
import matplotlib.pyplot as plt

# %%
dir = os.getcwd()
ori_df = pd.read_csv(f"{dir}\\{input()}.csv")
print(ori_df.info())
ori_df = ori_df.dropna()
print(ori_df.info())
df = ori_df[:]

print(df['TF'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    688 non-null    object
#  1   ssi     686 non-null    float64
#  2   hash    686 non-null    float64
#  3   cor     686 non-null    float64
#  4   chi     686 non-null    float64
#  5   inter   686 non-null    float64
#  6   bha     686 non-null    float64
#  7   TF      685 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 43.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 685 entries, 1 to 687
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    685 non-null    object
#  1   ssi     685 non-null    float64
#  2   hash    685 non-null    float64
#  3   cor     685 non-null    float64
#  4   chi     685 non-null    float64
#  5   inter   685 non-null    float64
#  6   bha     685 non-null    float64
#  7   TF      685 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 48.2+ KB
# None
# TF
# 0.0    437
# 1.0    248
# Name: count, dtype: int64

# %%
column = "ssi"
df[column] = ori_df[column].apply(lambda x: (round(x * 100) // 10))

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()
# Out:
# ssi
# 3    114
# 5    113
# 6    107
# 4    100
# 2     79
# 7     76
# 1     57
# 0     24
# 8     15
# Name: count, dtype: int64
#    ssi        TF
# 0    0  0.666667
# 1    1  0.228070
# 2    2  0.088608
# 3    3  0.228070
# 4    4  0.290000
# 5    5  0.539823
# 6    6  0.495327
# 7    7  0.434211
# 8    8  0.666667

# %%
column = "hash"
df[column] = ori_df[column].apply(lambda x: round(x/2))

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()
# Out:
# hash
# 15    113
# 16     98
# 17     90
# 14     89
# 13     80
# 18     62
# 19     46
# 12     40
# 10     17
# 20     15
# 11     11
# 21      8
# 9       6
# 22      5
# 8       2
# 6       1
# 25      1
# 7       1
# Name: count, dtype: int64
#     hash        TF
# 0      6  1.000000
# 1      7  1.000000
# 2      8  0.500000
# 3      9  0.500000
# 4     10  0.235294
# 5     11  0.181818
# 6     12  0.350000
# 7     13  0.425000
# 8     14  0.382022
# 9     15  0.283186
# 10    16  0.316327
# 11    17  0.344444
# 12    18  0.387097
# 13    19  0.413043
# 14    20  0.600000
# 15    21  0.625000
# 16    22  0.400000
# 17    25  1.000000

# %%
column = "cor"
df[column] = ori_df[column].apply(lambda x: (round(x * 100) // 10))

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()

#부정확하다고 보임 -> 컬럼 삭제
# Out:
# cor
# 10    206
# 9     171
# 0     139
# 8      46
# 7      26
# 1      24
# 6      21
# 2      18
# 3      14
# 5      11
# 4       9
# Name: count, dtype: int64
#     cor        TF
# 0     0  0.374101
# 1     1  0.250000
# 2     2  0.222222
# 3     3  0.142857
# 4     4  0.333333
# 5     5  0.545455
# 6     6  0.333333
# 7     7  0.461538
# 8     8  0.326087
# 9     9  0.228070
# 10   10  0.495146

# %%
column = "chi"
df[column] = ori_df[column].apply(lambda x: x)

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()
# Out:
# chi
# 0.012298        19
# 0.058000         1
# 1394.486619      1
# 2174.267041      1
# 87.992351        1
#                 ..
# 16669.951470     1
# 9975.460329      1
# 176.870012       1
# 0.440837         1
# 1061.567204      1
# Name: count, Length: 667, dtype: int64
#                chi   TF
# 0         0.011207  1.0
# 1         0.011541  1.0
# 2         0.011545  0.0
# 3         0.011648  0.0
# 4         0.011815  1.0
# ..             ...  ...
# 662   82201.095580  0.0
# 663   84190.011380  0.0
# 664  111684.231400  0.0
# 665  131215.535600  0.0
# 666  146125.895700  0.0
#
# [667 rows x 2 columns]

# %%
column = "inter"
df[column] = ori_df[column].apply(lambda x: (round(x * 100) // 10))

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()
# Out:
# inter
# 10    467
# 0     126
# 1      23
# 3      11
# 4      10
# 2      10
# 5       9
# 6       8
# 8       8
# 9       7
# 7       6
# Name: count, dtype: int64
#     inter        TF
# 0       0  0.388889
# 1       1  0.304348
# 2       2  0.200000
# 3       3  0.272727
# 4       4  0.100000
# 5       5  0.333333
# 6       6  0.375000
# 7       7  0.666667
# 8       8  0.375000
# 9       9  0.285714
# 10     10  0.366167

# %%
column = "bha"
df[column] = ori_df[column].apply(lambda x: (round(x * 100) // 10))

print(df[column].value_counts())
df_modi = df.groupby(column)["TF"].mean()

df_modi = df_modi.reset_index()
print(df_modi)

plt.figure(figsize=(8, 5))
plt.bar(df_modi[column], df_modi['TF'], color='skyblue')

plt.show()
# Out:
# bha
# 9     149
# 5      87
# 6      85
# 7      63
# 3      59
# 4      56
# 0      52
# 8      48
# 1      41
# 2      41
# 10      4
# Name: count, dtype: int64
#     bha        TF
# 0     0  0.403846
# 1     1  0.585366
# 2     2  0.634146
# 3     3  0.542373
# 4     4  0.321429
# 5     5  0.275862
# 6     6  0.282353
# 7     7  0.253968
# 8     8  0.250000
# 9     9  0.342282
# 10   10  0.000000

# %%
df_modi = df[:]
df_modi = df_modi.drop(["cor", "file"], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
y = df_modi["TF"]
X = df_modi.drop("TF", axis = 1)
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
X = pd.DataFrame(data=X, columns = ["ssi", "hash", "chi", "inter", "bha"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 123)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import f1_score

model = DecisionTreeClassifier(max_depth=3)
preds = []
for model in [DecisionTreeClassifier(max_depth=3), KNN(n_neighbors=3), GaussianNB(), LogisticRegression(), SVC()]:

    model.fit(X_train, y_train)
    print(model.score(X_test, y_test))

    pred = model.predict(X_test)
    print(f1_score(y_test, pred, average = None))
    preds.append(model.predict(X_test))
# Out:
# 0.7007299270072993
# 0.6788321167883211
# 0.583941605839416
# 0.6642335766423357
# 0.6861313868613139

# %%
whole = [0 for _ in len(y_test)]
for i in preds:
    whole += i
whole = list(map(lambda x: 1 if x >= 3 else 0, whole))
whole

accuracy = 0
for i in range(len(y_test)):
    if y_test.iloc[i] == whole[i]:
        accuracy += 1
accuracy = accuracy / len(y_test)
print(accuracy)
# Out:
# 0.6934306569343066
